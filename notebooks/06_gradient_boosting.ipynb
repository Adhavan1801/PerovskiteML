# %%
# !pip install --upgrade --force-reinstall numpy pandas mendeleev pymatgen -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 808.1 kB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 1.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 6.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.2/65.2 kB 5.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.6/55.6 kB 4.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 5.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 5.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.5/102.5 kB 10.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 65.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 61.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 66.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 69.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.8/301.8 kB 30.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 98.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.9/51.9 kB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 82.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 332.3/332.3 kB 25.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.8/14.8 MB 97.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 443.6/443.6 kB 35.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 79.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 865.8/865.8 kB 56.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 70.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 kB 23.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 509.2/509.2 kB 36.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 7.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.7/117.7 kB 12.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.6/37.6 MB 13.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 809.0/809.0 kB 53.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 89.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 110.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 8.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 347.8/347.8 kB 31.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.1/60.1 kB 6.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.6/159.6 kB 15.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.9/143.9 kB 15.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 326.2/326.2 kB 32.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 103.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 583.9/583.9 kB 46.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.4/70.4 kB 7.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 58.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 37.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.0/331.0 kB 32.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 7.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 98.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.1/111.1 kB 12.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 739.1/739.1 kB 50.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.8/45.8 kB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.7/128.7 kB 12.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.2/83.2 kB 8.7 MB/s eta 0:00:00
#   Building wheel for bibtexparser (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cublas-cu12==12.4.5.8; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cublas-cu12 12.5.3.2 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-cupti-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-cupti-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-nvrtc-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-nvrtc-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-runtime-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-runtime-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cudnn-cu12==9.1.0.70; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cudnn-cu12 9.3.0.75 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cufft-cu12==11.2.1.3; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cufft-cu12 11.2.3.61 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-curand-cu12==10.3.5.147; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-curand-cu12 10.3.6.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusolver-cu12==11.6.1.9; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusolver-cu12 11.6.3.83 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusparse-cu12==12.3.1.170; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusparse-cu12 12.5.1.3 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-nvjitlink-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-nvjitlink-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires sympy==1.13.1; python_version >= "3.9", but you have sympy 1.13.3 which is incompatible.
# langchain-core 0.3.55 requires packaging<25,>=23.2, but you have packaging 25.0 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.

# %% [markdown]
# **:IMPORTING REQIURED MODULES**

# %%
# !pip install CBFV -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 539.2/539.2 kB 8.0 MB/s eta 0:00:00

# %%
import pandas as pd
import numpy as np
from pymatgen.core import Composition, Element
from mendeleev import element
from CBFV.composition import generate_features

# %% [markdown]
# ***READING THE DATASET WITH HELP OF PANDAS MODULE***

# %%
import os; df = pd.read_excel('../data/perovskites.xlsx' if os.path.exists('../data/perovskites.xlsx') else ('data/perovskites.xlsx' if os.path.exists('data/perovskites.xlsx') else 'https://raw.githubusercontent.com/Adhavan1801/PerovskiteML/main/data/perovskites.xlsx'))

# %%
df
# Out:
#          formula  target
# 0      ReBTeGeO6  380.39
# 1      GeZnAl2O6  372.33
# 2     TcCaMnBeO6  359.72
# 3     ReSeAlCeO6  355.14
# 4     OsSeAlCeO6  352.48
# ..           ...     ...
# 583   Au2SeTeBr6   24.82
# 584  HgOsTeAgBr6   24.24
# 585  HgIrTeAgBr6   24.20
# 586  HgPtTeAgBr6   24.13
# 587  HgAuTeAgBr6   24.09
#
# [588 rows x 2 columns]

# %% [markdown]
# **GENERATING FEATURES WITH CBFV(Magpie)**

# %%
X, y, formulas, skipped = generate_features(
    df,
    elem_prop='magpie',  # Choose a featurization scheme (e.g., 'oliynyk', 'magpie')
    drop_duplicates=True,  # Keep duplicates if any
    extend_features=True,  # Extend features or not
    sum_feat=True
   )
# Out:
# /usr/local/lib/python3.11/dist-packages/CBFV/composition.py:217: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if df['formula'].value_counts()[0] > 1:
# Duplicate formula(e) removed using default pandas function
# Processing Input Data: 100%|██████████| 587/587 [00:00<00:00, 11389.66it/s]
# 	Featurizing Compositions...
# Assigning Features...: 100%|██████████| 587/587 [00:00<00:00, 2248.94it/s]
# 	Creating Pandas Objects...

# %%
X
# Out:
#      sum_Number  sum_MendeleevNumber  sum_AtomicWeight  sum_MeltingT  \
# 0         212.0                817.0        493.254400       8069.86
# 1         136.0                816.0        287.979477       4099.82
# 2         140.0                701.0        298.024627       6952.80
# 3         228.0                753.0        528.260939       6286.27
# 4         229.0                756.0        532.283939       6133.27
# ..          ...                  ...               ...           ...
# 582       454.0                881.0       1079.917138       5486.12
# 583       465.0                853.0       1105.712200       7092.71
# 584       466.0                856.0       1107.699200       6525.71
# 585       467.0                859.0       1110.566200       5828.11
# 586       468.0                862.0       1112.448769       5124.04
#
#      sum_Column  sum_Row  sum_CovalentRadius  sum_Electronegativity  \
# 0         146.0     29.0               889.0                  28.69
# 1         148.0     26.0               880.0                  27.52
# 2         114.0     27.0               954.0                  26.66
# 3         135.0     31.0               992.0                  27.82
# 4         136.0     31.0               985.0                  28.12
# ..          ...      ...                 ...                    ...
# 582       156.0     45.0              1250.0                  27.49
# 583       149.0     46.0              1279.0                  25.99
# 584       150.0     46.0              1276.0                  25.99
# 585       151.0     46.0              1271.0                  26.07
# 586       152.0     46.0              1271.0                  26.33
#
#      sum_NsValence  sum_NpValence  ...  mode_NValence  mode_NsUnfilled  \
# 0             20.0           31.0  ...            6.0              0.0
# 1             20.0           28.0  ...            6.0              0.0
# 2             20.0           24.0  ...            6.0              0.0
# 3             20.0           29.0  ...            6.0              0.0
# 4             20.0           29.0  ...            6.0              0.0
# ..             ...            ...  ...            ...              ...
# 582           18.0           38.0  ...           17.0              0.0
# 583           19.0           34.0  ...           17.0              0.0
# 584           19.0           34.0  ...           17.0              0.0
# 585           18.0           34.0  ...           17.0              0.0
# 586           18.0           34.0  ...           17.0              0.0
#
#      mode_NpUnfilled  mode_NdUnfilled  mode_NfUnfilled  mode_NUnfilled  \
# 0                2.0              0.0              0.0             2.0
# 1                2.0              0.0              0.0             2.0
# 2                2.0              0.0              0.0             2.0
# 3                2.0              0.0              0.0             2.0
# 4                2.0              0.0              0.0             2.0
# ..               ...              ...              ...             ...
# 582              1.0              0.0              0.0             1.0
# 583              1.0              0.0              0.0             1.0
# 584              1.0              0.0              0.0             1.0
# 585              1.0              0.0              0.0             1.0
# 586              1.0              0.0              0.0             1.0
#
#      mode_GSvolume_pa  mode_GSbandgap  mode_GSmagmom  mode_SpaceGroupNumber
# 0               9.105           0.000            0.0                   12.0
# 1               9.105           0.000            0.0                   12.0
# 2               9.105           0.000            0.0                   12.0
# 3               9.105           0.000            0.0                   12.0
# 4               9.105           0.000            0.0                   12.0
# ..                ...             ...            ...                    ...
# 582            29.480           1.457            0.0                   64.0
# 583            29.480           1.457            0.0                   64.0
# 584            29.480           1.457            0.0                   64.0
# 585            29.480           1.457            0.0                   64.0
# 586            29.480           1.457            0.0                   64.0
#
# [587 rows x 154 columns]

# %%
y
# Out:
# 0      380.39
# 1      372.33
# 2      359.72
# 3      355.14
# 4      352.48
#         ...
# 582     24.82
# 583     24.24
# 584     24.20
# 585     24.13
# 586     24.09
# Name: target, Length: 587, dtype: float64

# %%
formulas
# Out:
# 0        ReBTeGeO6
# 1        GeZnAl2O6
# 2       TcCaMnBeO6
# 3       ReSeAlCeO6
# 4       OsSeAlCeO6
#           ...
# 582     Au2SeTeBr6
# 583    HgOsTeAgBr6
# 584    HgIrTeAgBr6
# 585    HgPtTeAgBr6
# 586    HgAuTeAgBr6
# Name: formula, Length: 587, dtype: object

# %%
skipped
# Out:
# []

# %% [markdown]
# **COUNTING THE FEATURES GIVEN BY CBFV(Magpie)**

# %%
count=0
for feature in X.columns:
    count+=1
print("Total number of features extracted :",count)
# Out:
# Total number of features extracted : 154

# %% [markdown]
# #**FINDING THE COMPOSITION OF THE FORMULAS WITH HELP OF PYMATGEN**

# %%
comp = [formula for formula in df['formula']]

# %% [markdown]
# #**FINDING GEOMENTRIC FACTORS WHICH ARE NOT IN CBFV**

# %%
def featurize_pymatgen(formula):
  try:
        comp = Composition(formula)
        elements = list(comp.elements)
        k=str(comp)

        d=[]
        for i in k:
          if i.isdigit():
            d.append(i)


        # Mean properties
        mean_electronegativity = np.mean([el.X for el in elements if el.X is not None])
        mean_ionic_radii = np.mean([max(el.ionic_radii.values(), default=0) for el in elements])
        num_elements = len(elements)




        # Define A, B, and X site candidates
        x_site = next((el for el in elements if el.is_chalcogen or el.is_halogen), None)

        #print(b_elements)
        #print(x_site)
        #if elements[1]==elements[2] and num_elements==5:
        tolerance_factor, octahedral_factor, rho_A, rho_B = None, None, None, None
        if len(d)==4:

        # Case 1: A₂BB'X₆ (e.g., 2 A, 2 distinct B, 6 X)
          if  (d[0]=='2') and (d[1]=='1') and (d[2]=='1') :

              a_site = elements[0]
              b_site, b_prime_site = elements[1], elements[2]
              r_A = max(a_site.ionic_radii.values(), default=0)
              r_B = max(b_site.ionic_radii.values(), default=0)
              r_B_prime = max(b_prime_site.ionic_radii.values(), default=0)
              r_X = max(x_site.ionic_radii.values(), default=0)

              if r_A > 0 and r_B > 0 and r_B_prime > 0 and r_X > 0:
                  avg_r_B = (r_B + r_B_prime) / 2
                  tolerance_factor = (r_A + r_X) / (np.sqrt(2) * (avg_r_B + r_X))
                  octahedral_factor = avg_r_B / r_X
                  rho_A = (r_A - r_X) / (2 * r_X)
                  rho_B = (r_A - avg_r_B) / (2 * r_X)

        # Case 2: AA'B₂X₆ (e.g., 2 distinct A, 1 B type, 6 X)
          elif  (d[0]=='1') and (d[1]=='1') and (d[2]=='2'):

            a_site, a_prime_site = elements[0], elements[1]
            b_site = elements[2]
            r_A = max(a_site.ionic_radii.values(), default=0)

            r_A_prime = max(a_prime_site.ionic_radii.values(), default=0)

            r_B = max(b_site.ionic_radii.values(), default=0)
            r_X = max(x_site.ionic_radii.values(), default=0)

            if r_A > 0 and r_A_prime > 0 and r_B > 0 and r_X > 0:
                avg_r_A = (r_A + r_A_prime) / 2
                tolerance_factor = (avg_r_A + r_X) / (np.sqrt(2) * (r_B + r_X))
                octahedral_factor = r_B / r_X
                rho_A = (avg_r_A - r_X) / (2 * r_X)
                rho_B = (avg_r_A - r_B) / (2 * r_X)
        #AA'bbx6
        elif len(d)==3:
             a_site, a_prime_site = elements[0], elements[1]
             b_site = elements[2]
             r_A = max(a_site.ionic_radii.values(), default=0)

             r_A_prime = max(a_prime_site.ionic_radii.values(), default=0)

             r_B = max(b_site.ionic_radii.values(), default=0)
             r_X = max(x_site.ionic_radii.values(), default=0)

             if r_A > 0 and r_A_prime > 0 and r_B > 0 and r_X > 0:
                avg_r_A = (r_A + r_A_prime) / 2
                tolerance_factor = (avg_r_A + r_X) / (np.sqrt(2) * (r_B + r_X))
                octahedral_factor = r_B / r_X
                rho_A = (avg_r_A - r_X) / (2 * r_X)
                rho_B = (avg_r_A - r_B) / (2 * r_X)
        # Case 3: AA'BB'X₆ (e.g., 2 distinct A, 2 distinct B, 6 X)
        else:

            a_site, a_prime_site = elements[0], elements[1]
            b_site, b_prime_site = elements[2], elements[3]
            r_A = max(a_site.ionic_radii.values(), default=0)
            r_A_prime = max(a_prime_site.ionic_radii.values(), default=0)
            r_B = max(b_site.ionic_radii.values(), default=0)
            r_B_prime = max(b_prime_site.ionic_radii.values(), default=0)
            r_X = max(x_site.ionic_radii.values(), default=0)

            if r_A > 0 and r_A_prime > 0 and r_B > 0 and r_B_prime > 0 and r_X > 0:
                avg_r_A = (r_A + r_A_prime) / 2
                avg_r_B = (r_B + r_B_prime) / 2
                tolerance_factor = (avg_r_A + r_X) / (np.sqrt(2) * (avg_r_B + r_X))
                octahedral_factor = avg_r_B / r_X
                rho_A = (avg_r_A - r_X) / (2 * r_X)
                rho_B = (avg_r_A - avg_r_B) / (2 * r_X)

        # Return results
        return {

            "mean_electronegativity": mean_electronegativity,
            "mean_ionic_radii": mean_ionic_radii,
            "num_elements": num_elements,
            "tolerance_factor": tolerance_factor,
            "octahedral_factor": octahedral_factor,
            "mismatch_factor_A": rho_A,
            "mismatch_factor_B": rho_B
        }

  except Exception as e:
        print(f"Error featurizing {formula}: {e}")
        return {

            "mean_electronegativity": None,
            "mean_ionic_radii": None,
            "num_elements": None,
            "tolerance_factor": None,
            "octahedral_factor": None,
            "mismatch_factor_A": None,
            "mismatch_factor_B": None
        }

# %%
mean_electronegativity=[]
mean_ionic_radii=[]
tolerance_factor_d=[]
octahedral_factor=[]
mismatch_factor_A=[]
mismatch_factor_B=[]

for i in range(len(formulas)):
  features=featurize_pymatgen(formulas[i])

  mean_electronegativity.append(features['mean_electronegativity'])
  mean_ionic_radii.append(features['mean_ionic_radii'])
  tolerance_factor_d.append(features['tolerance_factor'])
  octahedral_factor.append(features['octahedral_factor'])
  mismatch_factor_A.append(features['mismatch_factor_A'])
  mismatch_factor_B.append(features['mismatch_factor_B'])

# %%
extra_features=pd.DataFrame( {

            "mean_electronegativity": mean_electronegativity,
            "mean_ionic_radii": mean_ionic_radii,
            "tolerance_factor": tolerance_factor_d,
            "octahedral_factor": octahedral_factor,
            "mismatch_factor_A": mismatch_factor_A,
            "mismatch_factor_B": mismatch_factor_B
        })

# %%
extra_features
# Out:
#      mean_electronegativity  mean_ionic_radii  tolerance_factor  \
# 0                    2.2980           1.07600          0.531329
# 1                    2.1775           0.92125          0.780193
# 2                    1.8920           0.94900          0.770365
# 3                    2.1240           1.13900          0.807939
# 4                    2.1840           1.13900          0.807939
# ..                      ...               ...               ...
# 582                  2.5375           1.81000          0.624192
# 583                  2.2380           1.45600          0.588313
# 584                  2.2380           1.46600          0.593027
# 585                  2.2540           1.49000          0.604341
# 586                  2.3060           1.60400          0.658081
#
#      octahedral_factor  mismatch_factor_A  mismatch_factor_B
# 0             0.710145          -0.357488          -0.212560
# 1             0.535714          -0.152778           0.079365
# 2             0.619048          -0.118056           0.072421
# 3             0.495924          -0.145380           0.106658
# 4             0.495924          -0.145380           0.106658
# ..                 ...                ...                ...
# 582           1.062500          -0.089674          -0.120924
# 583           0.811594          -0.246377          -0.152174
# 584           0.811594          -0.240338          -0.146135
# 585           0.811594          -0.225845          -0.131643
# 586           0.811594          -0.157005          -0.062802
#
# [587 rows x 6 columns]

# %%
x=pd.concat([X,extra_features],axis=1)

# %%
x
# Out:
#      sum_Number  sum_MendeleevNumber  sum_AtomicWeight  sum_MeltingT  \
# 0         212.0                817.0        493.254400       8069.86
# 1         136.0                816.0        287.979477       4099.82
# 2         140.0                701.0        298.024627       6952.80
# 3         228.0                753.0        528.260939       6286.27
# 4         229.0                756.0        532.283939       6133.27
# ..          ...                  ...               ...           ...
# 582       454.0                881.0       1079.917138       5486.12
# 583       465.0                853.0       1105.712200       7092.71
# 584       466.0                856.0       1107.699200       6525.71
# 585       467.0                859.0       1110.566200       5828.11
# 586       468.0                862.0       1112.448769       5124.04
#
#      sum_Column  sum_Row  sum_CovalentRadius  sum_Electronegativity  \
# 0         146.0     29.0               889.0                  28.69
# 1         148.0     26.0               880.0                  27.52
# 2         114.0     27.0               954.0                  26.66
# 3         135.0     31.0               992.0                  27.82
# 4         136.0     31.0               985.0                  28.12
# ..          ...      ...                 ...                    ...
# 582       156.0     45.0              1250.0                  27.49
# 583       149.0     46.0              1279.0                  25.99
# 584       150.0     46.0              1276.0                  25.99
# 585       151.0     46.0              1271.0                  26.07
# 586       152.0     46.0              1271.0                  26.33
#
#      sum_NsValence  sum_NpValence  ...  mode_GSvolume_pa  mode_GSbandgap  \
# 0             20.0           31.0  ...             9.105           0.000
# 1             20.0           28.0  ...             9.105           0.000
# 2             20.0           24.0  ...             9.105           0.000
# 3             20.0           29.0  ...             9.105           0.000
# 4             20.0           29.0  ...             9.105           0.000
# ..             ...            ...  ...               ...             ...
# 582           18.0           38.0  ...            29.480           1.457
# 583           19.0           34.0  ...            29.480           1.457
# 584           19.0           34.0  ...            29.480           1.457
# 585           18.0           34.0  ...            29.480           1.457
# 586           18.0           34.0  ...            29.480           1.457
#
#      mode_GSmagmom  mode_SpaceGroupNumber  mean_electronegativity  \
# 0              0.0                   12.0                  2.2980
# 1              0.0                   12.0                  2.1775
# 2              0.0                   12.0                  1.8920
# 3              0.0                   12.0                  2.1240
# 4              0.0                   12.0                  2.1840
# ..             ...                    ...                     ...
# 582            0.0                   64.0                  2.5375
# 583            0.0                   64.0                  2.2380
# 584            0.0                   64.0                  2.2380
# 585            0.0                   64.0                  2.2540
# 586            0.0                   64.0                  2.3060
#
#      mean_ionic_radii  tolerance_factor  octahedral_factor  mismatch_factor_A  \
# 0             1.07600          0.531329           0.710145          -0.357488
# 1             0.92125          0.780193           0.535714          -0.152778
# 2             0.94900          0.770365           0.619048          -0.118056
# 3             1.13900          0.807939           0.495924          -0.145380
# 4             1.13900          0.807939           0.495924          -0.145380
# ..                ...               ...                ...                ...
# 582           1.81000          0.624192           1.062500          -0.089674
# 583           1.45600          0.588313           0.811594          -0.246377
# 584           1.46600          0.593027           0.811594          -0.240338
# 585           1.49000          0.604341           0.811594          -0.225845
# 586           1.60400          0.658081           0.811594          -0.157005
#
#      mismatch_factor_B
# 0            -0.212560
# 1             0.079365
# 2             0.072421
# 3             0.106658
# 4             0.106658
# ..                 ...
# 582          -0.120924
# 583          -0.152174
# 584          -0.146135
# 585          -0.131643
# 586          -0.062802
#
# [587 rows x 160 columns]

# %% [markdown]
# #**IMPORTING MODULES FOR PREDICTION**

# %%
# !pip install lazypredict -q
from sklearn.feature_selection import RFE
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from lazypredict.Supervised import LazyRegressor
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.0/29.0 MB 54.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 82.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.9/231.9 kB 21.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 kB 14.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.9/114.9 kB 11.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 kB 8.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 692.3/692.3 kB 47.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.2/95.2 kB 10.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.4/203.4 kB 18.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 6.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 6.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 6.8 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.

# %% [markdown]
# # **SCALING THE DATASET**

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(x)
X_scaled = pd.DataFrame(X_scaled, columns=x.columns)

# %%
X_scaled
# Out:
#      sum_Number  sum_MendeleevNumber  sum_AtomicWeight  sum_MeltingT  \
# 0         -0.89                 0.03             -0.82          1.18
# 1         -1.80                 0.01             -1.83         -1.44
# 2         -1.76                -2.52             -1.78          0.44
# 3         -0.70                -1.37             -0.64          0.00
# 4         -0.69                -1.31             -0.62         -0.10
# ..          ...                  ...               ...           ...
# 582        2.01                 1.43              2.08         -0.52
# 583        2.14                 0.82              2.21          0.54
# 584        2.16                 0.89              2.22          0.16
# 585        2.17                 0.95              2.23         -0.30
# 586        2.18                 1.02              2.24         -0.76
#
#      sum_Column  sum_Row  sum_CovalentRadius  sum_Electronegativity  \
# 0          0.27    -1.19               -1.37                   0.96
# 1          0.50    -1.71               -1.43                   0.27
# 2         -3.30    -1.53               -0.96                  -0.23
# 3         -0.96    -0.84               -0.72                   0.45
# 4         -0.84    -0.84               -0.77                   0.62
# ..          ...      ...                 ...                    ...
# 582        1.39     1.58                0.89                   0.25
# 583        0.61     1.75                1.08                  -0.63
# 584        0.72     1.75                1.06                  -0.63
# 585        0.83     1.75                1.03                  -0.58
# 586        0.94     1.75                1.03                  -0.43
#
#      sum_NsValence  sum_NpValence  ...  mode_GSvolume_pa  mode_GSbandgap  \
# 0             0.73          -0.63  ...             -1.08           -1.09
# 1             0.73          -1.42  ...             -1.08           -1.09
# 2             0.73          -2.48  ...             -1.08           -1.09
# 3             0.73          -1.15  ...             -1.08           -1.09
# 4             0.73          -1.15  ...             -1.08           -1.09
# ..             ...            ...  ...               ...             ...
# 582          -1.68           1.22  ...              1.09            0.36
# 583          -0.47           0.17  ...              1.09            0.36
# 584          -0.47           0.17  ...              1.09            0.36
# 585          -1.68           0.17  ...              1.09            0.36
# 586          -1.68           0.17  ...              1.09            0.36
#
#      mode_GSmagmom  mode_SpaceGroupNumber  mean_electronegativity  \
# 0             0.00                  -1.11                    0.61
# 1             0.00                  -1.11                   -0.10
# 2             0.00                  -1.11                   -1.76
# 3             0.00                  -1.11                   -0.41
# 4             0.00                  -1.11                   -0.06
# ..             ...                    ...                     ...
# 582           0.00                   0.91                    2.01
# 583           0.00                   0.91                    0.26
# 584           0.00                   0.91                    0.26
# 585           0.00                   0.91                    0.35
# 586           0.00                   0.91                    0.66
#
#      mean_ionic_radii  tolerance_factor  octahedral_factor  mismatch_factor_A  \
# 0               -1.24             -1.24              -0.14              -1.58
# 1               -2.33              1.66              -1.78               0.88
# 2               -2.13              1.55              -0.99               1.29
# 3               -0.80              1.99              -2.15               0.97
# 4               -0.80              1.99              -2.15               0.97
# ..                ...               ...                ...                ...
# 582              3.93             -0.16               3.18               1.64
# 583              1.44             -0.58               0.82              -0.24
# 584              1.51             -0.52               0.82              -0.17
# 585              1.68             -0.39               0.82               0.00
# 586              2.48              0.24               0.82               0.83
#
#      mismatch_factor_B
# 0                -1.19
# 1                 1.61
# 2                 1.54
# 3                 1.87
# 4                 1.87
# ..                 ...
# 582              -0.31
# 583              -0.61
# 584              -0.56
# 585              -0.42
# 586               0.24
#
# [587 rows x 160 columns]

# %% [markdown]
# #**SPLITING THE DATASET FOR TRAIN AND TEST**

# %%
text_data = df["formula"]

# %%
X_train, X_test, y_train, y_test, text_train, text_test = train_test_split(
    X_scaled, y, text_data, test_size=0.2, random_state=42
)

# %%
reg = LazyRegressor(verbose=0, ignore_warnings=True, random_state=42)
models, predictions = reg.fit(X_train, X_test, y_train, y_test)
# Out:
#   0%|          | 0/42 [00:00<?, ?it/s]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000673 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 6432
# [LightGBM] [Info] Number of data points in the train set: 469, number of used features: 144
# [LightGBM] [Info] Start training from score 111.309147
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf

# %%
models
# Out:
#                                                            Adjusted R-Squared  \
# Model
# Lars                          15564455128405278359809593909010401033453568.00
# KernelRidge                                                             10.57
# GaussianProcessRegressor                                                10.09
# QuantileRegressor                                                        3.88
# DummyRegressor                                                           3.72
# LarsCV                                                                   3.35
# NuSVR                                                                    3.06
# SVR                                                                      3.05
# RANSACRegressor                                                          2.80
# LinearSVR                                                                2.52
# OrthogonalMatchingPursuitCV                                              2.28
# OrthogonalMatchingPursuit                                                2.28
# PassiveAggressiveRegressor                                               2.27
# LassoLarsIC                                                              2.23
# LassoLars                                                                2.23
# LassoLarsCV                                                              2.23
# TransformedTargetRegressor                                               2.22
# LinearRegression                                                         2.22
# TweedieRegressor                                                         2.19
# GammaRegressor                                                           2.19
# SGDRegressor                                                             2.18
# ElasticNet                                                               2.17
# Lasso                                                                    2.14
# DecisionTreeRegressor                                                    2.14
# MLPRegressor                                                             2.13
# BayesianRidge                                                            2.11
# ElasticNetCV                                                             2.10
# LassoCV                                                                  2.10
# PoissonRegressor                                                         2.08
# Ridge                                                                    2.08
# RidgeCV                                                                  2.08
# AdaBoostRegressor                                                        2.08
# HuberRegressor                                                           2.07
# KNeighborsRegressor                                                      1.99
# BaggingRegressor                                                         1.86
# ExtraTreeRegressor                                                       1.80
# LGBMRegressor                                                            1.77
# RandomForestRegressor                                                    1.76
# XGBRegressor                                                             1.75
# GradientBoostingRegressor                                                1.74
# HistGradientBoostingRegressor                                            1.73
# ExtraTreesRegressor                                                      1.67
#
#                                                                     R-Squared  \
# Model
# Lars                          -5720269833516470004417035948195828356612096.00
# KernelRidge                                                             -2.52
# GaussianProcessRegressor                                                -2.34
# QuantileRegressor                                                       -0.06
# DummyRegressor                                                          -0.00
# LarsCV                                                                   0.14
# NuSVR                                                                    0.24
# SVR                                                                      0.25
# RANSACRegressor                                                          0.34
# LinearSVR                                                                0.44
# OrthogonalMatchingPursuitCV                                              0.53
# OrthogonalMatchingPursuit                                                0.53
# PassiveAggressiveRegressor                                               0.53
# LassoLarsIC                                                              0.55
# LassoLars                                                                0.55
# LassoLarsCV                                                              0.55
# TransformedTargetRegressor                                               0.55
# LinearRegression                                                         0.55
# TweedieRegressor                                                         0.56
# GammaRegressor                                                           0.56
# SGDRegressor                                                             0.57
# ElasticNet                                                               0.57
# Lasso                                                                    0.58
# DecisionTreeRegressor                                                    0.58
# MLPRegressor                                                             0.58
# BayesianRidge                                                            0.59
# ElasticNetCV                                                             0.59
# LassoCV                                                                  0.60
# PoissonRegressor                                                         0.60
# Ridge                                                                    0.60
# RidgeCV                                                                  0.60
# AdaBoostRegressor                                                        0.60
# HuberRegressor                                                           0.61
# KNeighborsRegressor                                                      0.64
# BaggingRegressor                                                         0.68
# ExtraTreeRegressor                                                       0.71
# LGBMRegressor                                                            0.72
# RandomForestRegressor                                                    0.72
# XGBRegressor                                                             0.72
# GradientBoostingRegressor                                                0.73
# HistGradientBoostingRegressor                                            0.73
# ExtraTreesRegressor                                                      0.75
#
#                                                      RMSE  Time Taken
# Model
# Lars                          145676075396903131414528.00        0.20
# KernelRidge                                        114.23        0.06
# GaussianProcessRegressor                           111.34        0.21
# QuantileRegressor                                   62.68        4.89
# DummyRegressor                                      60.91        0.02
# LarsCV                                              56.59        0.85
# NuSVR                                               53.00        0.12
# SVR                                                 52.87        0.07
# RANSACRegressor                                     49.59        3.13
# LinearSVR                                           45.51        0.09
# OrthogonalMatchingPursuitCV                         41.82        0.13
# OrthogonalMatchingPursuit                           41.75        0.05
# PassiveAggressiveRegressor                          41.67        0.07
# LassoLarsIC                                         41.00        0.11
# LassoLars                                           41.00        0.05
# LassoLarsCV                                         41.00        0.21
# TransformedTargetRegressor                          40.76        0.03
# LinearRegression                                    40.76        0.08
# TweedieRegressor                                    40.32        0.34
# GammaRegressor                                      40.29        0.10
# SGDRegressor                                        40.05        0.06
# ElasticNet                                          39.89        0.04
# Lasso                                               39.49        0.14
# DecisionTreeRegressor                               39.49        0.13
# MLPRegressor                                        39.29        2.45
# BayesianRidge                                       38.84        0.28
# ElasticNetCV                                        38.79        7.36
# LassoCV                                             38.66        6.66
# PoissonRegressor                                    38.44        0.85
# Ridge                                               38.31        0.15
# RidgeCV                                             38.31        0.07
# AdaBoostRegressor                                   38.30        0.58
# HuberRegressor                                      38.19        0.61
# KNeighborsRegressor                                 36.72        0.06
# BaggingRegressor                                    34.22        0.29
# ExtraTreeRegressor                                  33.05        0.11
# LGBMRegressor                                       32.33        0.25
# RandomForestRegressor                               32.19        2.43
# XGBRegressor                                        32.07        0.74
# GradientBoostingRegressor                           31.73        2.09
# HistGradientBoostingRegressor                       31.46        0.97
# ExtraTreesRegressor                                 30.19        3.13

# %% [markdown]
# #**5. GRADIENT BOOSTING REGRESSOR**

# %%
import pandas as pd
import numpy as np
from pymatgen.core import Composition, Element
from CBFV.composition import generate_features
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import RFE
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from lazypredict.Supervised import LazyRegressor
import matplotlib.pyplot as plt

# Step 3: Load the dataset

gb_model = GradientBoostingRegressor(n_estimators=100, random_state=42)
rfe = RFE(estimator=gb_model, n_features_to_select=20)
rfe.fit(X_scaled, y)
selected_features = X_scaled.columns[rfe.support_]
X_rfe = X_scaled[selected_features]
print("Selected features:", selected_features)

#g
X_train, X_test, y_train, y_test = train_test_split(X_rfe, y, test_size=0.2, random_state=42)

# Initialize and train the Gradient Boosting Regressor
gbr = GradientBoostingRegressor(n_estimators=100, random_state=42)
gbr.fit(X_train, y_train)

# Make predictions
y_pred = gbr.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error:", mse)
print("R² Score:", r2)

# Fit the model
# Out:
# Selected features: Index(['sum_Number', 'sum_AtomicWeight', 'sum_NValence', 'sum_NUnfilled',
#        'sum_SpaceGroupNumber', 'avg_NValence', 'dev_Number', 'dev_Column',
#        'dev_NdValence', 'dev_NpUnfilled', 'dev_NdUnfilled', 'range_MeltingT',
#        'range_CovalentRadius', 'range_NValence', 'max_MendeleevNumber',
#        'max_CovalentRadius', 'max_NValence', 'min_AtomicWeight',
#        'mean_ionic_radii', 'mismatch_factor_A'],
#       dtype='object')
# Mean Squared Error: 1205.1382916926452
# R² Score: 0.6751544395249536

# %%
import matplotlib.pyplot as plt

# Scatter plot: Actual vs Predicted
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred, color='dodgerblue', edgecolor='k', alpha=0.7)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)  # Perfect prediction line
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Actual vs Predicted Values - GBR (before HyperParameter Tuning)')
plt.grid(True)
plt.tight_layout()
plt.show()
print("Mean Squared Error:", mse)
print("R² Score:", r2)
# Out:
# Mean Squared Error: 1205.1382916926452
# R² Score: 0.6751544395249536

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import GradientBoostingRegressor

# Reduced and faster parameter grid
param_grid = {
    'n_estimators': [100, 150],
    'learning_rate': [0.05, 0.1],
    'max_depth': [3, 5],
    'subsample': [0.8, 1.0]
}

# Initialize model
gbr = GradientBoostingRegressor(random_state=42)

# Grid search with 3-fold CV (faster)
grid_search = GridSearchCV(
    estimator=gbr,
    param_grid=param_grid,
    cv=3,
    n_jobs=-1,
    scoring='r2',
    verbose=1
)

# Fit on training data
grid_search.fit(X_train, y_train)

# Best model
best_gbr = grid_search.best_estimator_
print("Best Parameters:", grid_search.best_params_)

# Predict & Evaluate
y_pred_best = best_gbr.predict(X_test)
from sklearn.metrics import mean_squared_error, r2_score
print("Tuned MSE:", mean_squared_error(y_test, y_pred_best))
print("Tuned R² Score:", r2_score(y_test, y_pred_best))
# Out:
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# Best Parameters: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 150, 'subsample': 0.8}
# Tuned MSE: 852.3275602022388
# Tuned R² Score: 0.7702547285147268

# %%
import matplotlib.pyplot as plt

# Scatter plot: Actual vs Predicted (after tuning)
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred_best, color='mediumseagreen', edgecolor='k', alpha=0.7)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)  # Reference line
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Actual vs Predicted Values (Tuned GBR) after Hyper parameter ')
plt.grid(True)
plt.tight_layout()
plt.show()
print("Tuned MSE:", mean_squared_error(y_test, y_pred_best))
print("Tuned R² Score:", r2_score(y_test, y_pred_best))
# Out:
# Tuned MSE: 852.3275602022388
# Tuned R² Score: 0.7702547285147268
